# %% [markdown]
# # X AI
# Explaining decisions made by artificial intelligence systems can help provide transparency on how the model arrives at its decision. For example, explainable AI could be used to explain an autonomous vehicles reasoning on why it decided not to stop or slow down before hitting a pedestrian crossing the street.
#
# ## Things that we are going to explore.
# 1. eli5 libraly

# %%
# !pip install eli5

# %%
import pandas as pd
import numpy as np
from sklearn.datasets import make_regression,make_classification
from sklearn.datasets import fetch_20newsgroups

from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LinearRegression

import eli5

# %% [markdown]
# ## Creating mockup data/ test data
#
# using sklearn.datasets make_regression and make_classification

# %%
eli5_dat = make_regression(
    n_samples=100, 
    n_features=15, 
    n_informative=2, 
    n_targets=1, 
    bias=10, effective_rank=None, tail_strength=0.5, 
    noise=0.1, shuffle=True, coef=False, random_state=None)
clf_dat = make_classification(
    n_samples=100, 
    n_features=15, 
    n_informative=5, 
    n_redundant=2, n_repeated=1, 
    n_classes=5, n_clusters_per_class=2, 
    weights=None, flip_y=0.01, class_sep=1.0, 
    hypercube=True, shift=0.0, scale=1.0, shuffle=True, random_state=None)



categories = ['alt.atheism', 'soc.religion.christian',
              'comp.graphics', 'sci.med']
twenty_train = fetch_20newsgroups(
    subset='train',
    categories=categories,
    shuffle=True,
    random_state=42
)
twenty_test = fetch_20newsgroups(
    subset='test',
    categories=categories,
    shuffle=True,
    random_state=42
)

# %%
twenty_train.keys()
# Out:
# dict_keys(['data', 'filenames', 'target_names', 'target', 'DESCR'])

# %%
X,y = reg_dat
reg = LinearRegression()
reg.fit(X,y)
eli5.show_weights(reg)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <p style="margin-bottom: 0.5em; margin-top: 0em">
#             <b>
#
#         y
#
# </b>
#
# top features
#         </p>
#
#     <table class="eli5-weights"
#            style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto; margin-bottom: 2em;">
#         <thead>
#         <tr style="border: none;">
#
#                 <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;" title="Feature weights. Note that weights do not account for feature value scales, so if feature values have different scales, features with highest weights might not be the most important.">
#                     Weight<sup>?</sup>
#                 </th>
#
#             <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#
#         </tr>
#         </thead>
# ...

# %%
X,y = clf_dat

clf = RandomForestClassifier()
clf.fit(X,y)
eli5.show_weights(clf,vec=[f"test_{i}" for i in range(15)])
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#         <table class="eli5-weights eli5-feature-importances" style="border-collapse: collapse; border: none; margin-top: 0em; table-layout: auto;">
#     <thead>
#     <tr style="border: none;">
#         <th style="padding: 0 1em 0 0.5em; text-align: right; border: none;">Weight</th>
#         <th style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">Feature</th>
#     </tr>
#     </thead>
#     <tbody>
#
#         <tr style="background-color: hsl(120, 100.00%, 80.00%); border: none;">
#             <td style="padding: 0 1em 0 0.5em; text-align: right; border: none;">
#                 0.1160
#
#                     &plusmn; 0.1247
#
#             </td>
#             <td style="padding: 0 0.5em 0 0.5em; text-align: left; border: none;">
#                 x4
#             </td>
#         </tr>
# ...
